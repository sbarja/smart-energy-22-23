# %% [markdown]
# <img src="figuras/cabecera.png" alt="Drawing" style="width: 1000px;"/>

# %% [markdown]
# # SOLUCIÓN ejercicio de aprendizaje supervisado: regresión.
#
# ## *Predicción de consumo en un edificio de oficinas para el día siguiente*

# %% [markdown]
# ## Recordatorio: proceso de creación de un modelo de Machine Learning
#
# <img src="figuras/creacion-modeloML.png" alt="Drawing" style="width: 800px;"/>

# %% [markdown]
# ### DATA SET
#
# ### `regresion-edificio.xlsx`
#
# ### Features/características
# * **diasemana**: indica si el día es laborable (lunes a viernes) o findesemana (sábado a domingo).
# * **temp**: temperatura en (ºC).
# * **op_nubes**: opacidad de las nubes. Cuanto más alto es este valor, más cubierto está el cielo (%).
# * **temp_rocio**: temperatura de rocío (ºC).
# * **irrad**: irradiancia (W/m2)
# * **col_agua**: Agua precipitable. Es el total de vapor de agua en la columna atmosférica (mm).
# * **hum_rel**: Humedad relativa (%).
# * **rand**: Variable aleatoria.
# * **presion**: Presión atmosférica.
# * **dir_viento**: Dirección del viento.
# * **vel_viento**: Velocidad del viento en m/s.
# * **vel_viento_2**: Velocidad del viento en km/h.
#
# ### Target / etiqueta
#
# * **consumo**: Consumo del edificio de oficinas en kWh

# %% [markdown]
# ## **1. Importar librerías y datos**

# %%
# Importamos las librerías necesarias

import sklearn
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Cargamos el conjunto de datos de entrada
data = pd.read_excel('dataset/EJ2-regresion-edificio.xlsx')

# %%
data
# Out:
#                fechahora    diasemana  temp  op_nubes  temp_rocio  irrad  \
# 0    2020-03-01 00:00:00  findesemana  12.6      20.5         6.8    0.0
# 1    2020-03-01 01:00:00  findesemana  11.8      21.6         7.5    0.0
# 2    2020-03-01 02:00:00  findesemana  11.0      25.1         7.7    0.0
# 3    2020-03-01 03:00:00  findesemana  10.5      58.0         7.6    0.0
# 4    2020-03-01 04:00:00  findesemana  10.4      53.8         7.7    0.0
# ...                  ...          ...   ...       ...         ...    ...
# 9400 2021-03-27 17:00:00  findesemana  12.6      51.4         7.8   39.0
# 9401 2021-03-27 18:00:00  findesemana  11.7      93.4         7.7    0.0
# 9402 2021-03-27 19:00:00  findesemana  11.1      95.7         7.5    0.0
# 9403 2021-03-27 20:00:00  findesemana  10.6      94.9         7.3    0.0
# 9404 2021-03-27 21:00:00  findesemana  10.4      92.1         7.3    0.0
#
#       precip_agua  hum_rel   rand  presion  dir_viento  vel_viento  \
# 0            18.4     68.1  93854    979.3         121         1.4
# 1            18.4     74.8   4852    979.1         121         2.1
# 2            18.2     80.3   5365    978.5         125         2.1
# 3            17.9     82.5   4867    978.3         130         1.7
# 4            18.9     83.4   4131    978.5         144         1.8
# ...           ...      ...    ...      ...         ...         ...
# 9400         15.2     72.4   5076    996.4         176         2.1
# 9401         14.7     76.6   6478    996.7         188         1.7
# 9402         14.1     78.9   9067    997.1         204         1.3
# 9403         13.7     80.0   8624    997.4         211         1.2
# 9404         13.4     80.9   8771    997.6         220         1.1
#
#       vel_viento_2  consumo
# 0             5.04    4.269
# 1             7.56    4.246
# 2             7.56    4.261
# 3             6.12    4.232
# 4             6.48    4.237
# ...            ...      ...
# 9400          7.56    8.175
# 9401          6.12    7.812
# 9402          4.68    7.863
# 9403          4.32   10.384
# 9404          3.96    8.904
#
# [9405 rows x 14 columns]

# %% [markdown]
# ## **2. Comprender los datos**
#
# Es necesario visualizar y comprender los datos con los que vamos a trabajar, así como conocer sus características.
#
# 1. ¿Cuántos datos hay? ¿Cuántos atributos hay en los datos?
# 2. Resumen estadístico del conjunto de datos de entrada.
# 3. ¿Falta algún dato?

# %% [markdown]
# **1. ¿Cuántos datos hay?**  **¿Cuántos atributos hay en los datos?**

# %%
# Filasxcolumnas de los datos
data.shape
# Out:
# (9405, 14)

# %%
# Observa las primeras 5 filas de los datos para ver como son. 

data.head(50)
# Out:
#              fechahora    diasemana  temp  op_nubes  temp_rocio  irrad  \
# 0  2020-03-01 00:00:00  findesemana  12.6      20.5         6.8    0.0
# 1  2020-03-01 01:00:00  findesemana  11.8      21.6         7.5    0.0
# 2  2020-03-01 02:00:00  findesemana  11.0      25.1         7.7    0.0
# 3  2020-03-01 03:00:00  findesemana  10.5      58.0         7.6    0.0
# 4  2020-03-01 04:00:00  findesemana  10.4      53.8         7.7    0.0
# 5  2020-03-01 05:00:00  findesemana  10.5      57.6         8.0    0.0
# 6  2020-03-01 06:00:00  findesemana  10.6      47.4         8.3    6.0
# 7  2020-03-01 07:00:00  findesemana  11.0      14.1         7.8  136.0
# 8  2020-03-01 08:00:00  findesemana  11.9       0.6         6.5  331.0
# 9  2020-03-01 09:00:00  findesemana  13.5       0.7         4.7  491.0
# 10 2020-03-01 10:00:00  findesemana  15.1       0.0         3.4  614.0
# 11 2020-03-01 11:00:00  findesemana  16.1       4.0         3.4  649.0
# 12 2020-03-01 12:00:00  findesemana  16.8      11.9         4.1    NaN
# 13 2020-03-01 13:00:00  findesemana  17.1       7.9         4.3  568.0
# 14 2020-03-01 14:00:00  findesemana  17.2      13.6         4.1  435.0
# 15 2020-03-01 15:00:00  findesemana  17.1       3.3         4.1  331.0
# 16 2020-03-01 16:00:00  findesemana  16.7       0.9         4.5  162.0
# 17 2020-03-01 17:00:00  findesemana  15.7       0.0         5.2   20.0
# 18 2020-03-01 18:00:00  findesemana  14.9       0.0         5.3    0.0
# 19 2020-03-01 19:00:00  findesemana  14.4      21.7         5.2    0.0
# 20 2020-03-01 20:00:00  findesemana  13.9      41.7         5.1    0.0
# 21 2020-03-01 21:00:00  findesemana  13.5       0.1         5.2    0.0
# 22 2020-03-01 22:00:00  findesemana  13.4       0.0         5.3    0.0
# 23 2020-03-01 23:00:00  findesemana  13.2       5.3         5.6    0.0
# 24 2020-03-02 00:00:00      laboral  13.0      61.5         6.0    0.0
# 25 2020-03-02 01:00:00      laboral  13.0      61.6         7.3    0.0
# 26 2020-03-02 02:00:00      laboral  12.9      63.9         9.1    0.0
# 27 2020-03-02 03:00:00      laboral  13.0      88.4         9.9    0.0
# 28 2020-03-02 04:00:00      laboral  13.3      87.0         9.8    0.0
# 29 2020-03-02 05:00:00      laboral  13.7      82.9         9.8    0.0
# 30 2020-03-02 06:00:00      laboral  14.0      87.7         9.8    2.0
# 31 2020-03-02 07:00:00      laboral  14.0      73.6         9.5   42.0
# 32 2020-03-02 08:00:00      laboral  13.9      62.8         7.9  123.0
# 33 2020-03-02 09:00:00      laboral  14.6      23.2         5.2  391.0
# 34 2020-03-02 10:00:00      laboral  15.5       1.1         3.5  616.0
# 35 2020-03-02 11:00:00      laboral  16.0      12.3         3.0  602.0
# 36 2020-03-02 12:00:00      laboral  16.1       8.9         3.1  627.0
# 37 2020-03-02 13:00:00      laboral  16.0      10.1         2.1  569.0
# 38 2020-03-02 14:00:00      laboral  15.5      37.8        -0.2  323.0
# 39 2020-03-02 15:00:00      laboral  14.8       8.3        -2.1  327.0
# 40 2020-03-02 16:00:00      laboral  14.0       0.0        -2.5  179.0
# 41 2020-03-02 17:00:00      laboral  12.5       0.0        -1.4   25.0
# 42 2020-03-02 18:00:00      laboral  11.1       0.0        -0.8    0.0
# 43 2020-03-02 19:00:00      laboral  10.3       0.0        -1.3    0.0
# 44 2020-03-02 20:00:00      laboral   9.8       0.0        -1.5    0.0
# 45 2020-03-02 21:00:00      laboral   9.3       0.0        -1.9    0.0
# 46 2020-03-02 22:00:00      laboral   8.9       0.0        -2.2    0.0
# 47 2020-03-02 23:00:00      laboral   8.3       0.0        -1.9    0.0
# 48 2020-03-03 00:00:00      laboral   7.8       0.0        -1.5    0.0
# 49 2020-03-03 01:00:00      laboral   7.4       0.0        -1.5    0.0
#
#     precip_agua  hum_rel   rand  presion  dir_viento  vel_viento  \
# 0          18.4     68.1  93854    979.3         121         1.4
# 1          18.4     74.8   4852    979.1         121         2.1
# 2          18.2     80.3   5365    978.5         125         2.1
# 3          17.9     82.5   4867    978.3         130         1.7
# 4          18.9     83.4   4131    978.5         144         1.8
# 5          19.3     85.0   5540    978.6         148         2.4
# 6          16.8     85.5   7536    978.5         147         2.2
# 7          13.6     80.7   8845    978.5         159         1.5
# 8          12.2     69.3   5645    978.6         246         1.4
# 9          11.7     55.4   7290    978.6         272         4.3
# 10         11.7     45.5   8424    978.4         271         6.9
# 11         12.0     42.5   9355    977.8         267         7.6
# 12         12.1     42.9   3102    977.4         265         8.3
# 13         12.2     42.6   6302    977.1         262         9.0
# 14         12.3     41.9   4463    976.9         259         8.7
# 15         12.3     42.0   6776    976.6         257         8.1
# 16         12.7     44.4   8997    976.5         248         7.0
# 17         13.3     49.5   6183    977.1         239         6.0
# 18         13.1     52.7   5457    977.8         240         5.2
# 19         12.3     53.7   8765    977.8         241         4.5
# 20         13.1     55.5   5578    977.2         240         3.7
# 21         15.4     57.1   5956    976.9         243         3.1
# 22         16.8     58.3   4412    976.4         244         3.3
# 23         17.4     59.9   5349    975.0         233         3.6
# 24         18.8     62.4   6972    973.6         231         4.1
# 25         21.7     68.4   9389    972.2         230         5.3
# 26         23.9     77.9   7415    970.0         219         7.0
# 27         24.5     81.5   5529    968.1         217         8.2
# 28         24.6     79.1   3951    966.9         223         9.4
# 29         23.6     77.4   8161    965.8         230        10.0
# 30         21.7     75.7   6477    964.5         231        10.1
# 31         20.8     74.4   8203    963.8         234        11.7
# 32         17.9     66.8   3124    963.5         244        11.6
# 33         13.0     53.4   6259    963.0         255        10.7
# 34         10.9     44.7   4027    963.2         266        11.1
# 35         10.6     41.8   4328    964.3         278        10.0
# 36         10.7     41.8   7119    965.6         284         9.3
# 37         10.8     39.4   9583    966.2         292         8.6
# 38          9.6     34.1   6350    967.1         310         6.5
# 39          8.0     31.1   8565    968.5         316         4.1
# 40          6.9     32.0   3905    969.8         297         2.3
# 41          7.1     38.2   3032    971.7         277         1.8
# 42          7.4     43.7   5628    973.6         283         3.3
# 43          7.0     44.4   5627    974.7         289         4.6
# 44          6.7     45.3   3325    975.6         293         4.8
# 45          6.3     45.7   7473    976.8         298         5.0
# 46          6.3     45.9   3456    977.9         298         5.1
# 47          6.3     48.6   5189    978.8         306         4.2
# 48          6.1     51.8   4130    979.3         314         3.5
# 49          6.2     52.9   7949    979.6         304         3.6
#
#     vel_viento_2  consumo
# 0           5.04    4.269
# 1           7.56    4.246
# 2           7.56    4.261
# 3           6.12    4.232
# 4           6.48    4.237
# 5           8.64    4.280
# 6           7.92    4.210
# 7           5.40    4.345
# 8           5.04    3.263
# 9          15.48    3.252
# 10         24.84    3.252
# 11         27.36    3.204
# 12         29.88    5.525
# 13         32.40    4.838
# 14         31.32    4.874
# 15         29.16    4.663
# 16         25.20   12.416
# 17         21.60   12.376
# 18         18.72    3.281
# 19         16.20    4.753
# 20         13.32    4.442
# 21         11.16    4.375
# 22         11.88    4.229
# 23         12.96    4.251
# 24         14.76    4.242
# 25         19.08    4.250
# 26         25.20    4.239
# 27         29.52    4.208
# 28         33.84    4.266
# 29         36.00    4.241
# 30         36.36    4.233
# 31         42.12   43.659
# 32         41.76   30.517
# 33         38.52   30.884
# 34         39.96   26.171
# 35         36.00   27.943
# 36         33.48   33.369
# 37         30.96   32.720
# 38         23.40   29.562
# 39         14.76   29.879
# 40          8.28   31.360
# 41          6.48   28.052
# 42         11.88   36.514
# 43         16.56   31.302
# 44         17.28   10.141
# 45         18.00    5.975
# 46         18.36    4.398
# 47         15.12    4.324
# 48         12.60    4.444
# 49         12.96    4.322

# %%
# Formato de los datos: (enteros, obj, string, etc.)

data.dtypes
    
# fechahora -- todatetime
# diasemana -- LabelEncoder
# Out:
# fechahora       datetime64[ns]
# diasemana               object
# temp                   float64
# op_nubes               float64
# temp_rocio             float64
# irrad                  float64
# precip_agua            float64
# hum_rel                float64
# rand                     int64
# presion                float64
# dir_viento               int64
# vel_viento             float64
# vel_viento_2           float64
# consumo                float64
# dtype: object

# %%
# Si hay atributos categóricos, convertirlos a tipo int

from sklearn.preprocessing import LabelEncoder

# data 
lab_encoder = LabelEncoder() 
lab_encoder.fit(data['diasemana'])  
data['diasemana'] = lab_encoder.transform(data['diasemana'])

# %%
data
# Out:
#                fechahora  diasemana  temp  op_nubes  temp_rocio  irrad  \
# 0    2020-03-01 00:00:00          0  12.6      20.5         6.8    0.0
# 1    2020-03-01 01:00:00          0  11.8      21.6         7.5    0.0
# 2    2020-03-01 02:00:00          0  11.0      25.1         7.7    0.0
# 3    2020-03-01 03:00:00          0  10.5      58.0         7.6    0.0
# 4    2020-03-01 04:00:00          0  10.4      53.8         7.7    0.0
# ...                  ...        ...   ...       ...         ...    ...
# 9400 2021-03-27 17:00:00          0  12.6      51.4         7.8   39.0
# 9401 2021-03-27 18:00:00          0  11.7      93.4         7.7    0.0
# 9402 2021-03-27 19:00:00          0  11.1      95.7         7.5    0.0
# 9403 2021-03-27 20:00:00          0  10.6      94.9         7.3    0.0
# 9404 2021-03-27 21:00:00          0  10.4      92.1         7.3    0.0
#
#       precip_agua  hum_rel   rand  presion  dir_viento  vel_viento  \
# 0            18.4     68.1  93854    979.3         121         1.4
# 1            18.4     74.8   4852    979.1         121         2.1
# 2            18.2     80.3   5365    978.5         125         2.1
# 3            17.9     82.5   4867    978.3         130         1.7
# 4            18.9     83.4   4131    978.5         144         1.8
# ...           ...      ...    ...      ...         ...         ...
# 9400         15.2     72.4   5076    996.4         176         2.1
# 9401         14.7     76.6   6478    996.7         188         1.7
# 9402         14.1     78.9   9067    997.1         204         1.3
# 9403         13.7     80.0   8624    997.4         211         1.2
# 9404         13.4     80.9   8771    997.6         220         1.1
#
#       vel_viento_2  consumo
# 0             5.04    4.269
# 1             7.56    4.246
# 2             7.56    4.261
# 3             6.12    4.232
# 4             6.48    4.237
# ...            ...      ...
# 9400          7.56    8.175
# 9401          6.12    7.812
# 9402          4.68    7.863
# 9403          4.32   10.384
# 9404          3.96    8.904
#
# [9405 rows x 14 columns]

# %%
# Si hay atributos de tipo fecha, transformarlos a datetime para operar con ellos
data['datetime'] = pd.to_datetime(data['fechahora'], format='%Y/%m/%d %H:%M')
data['hora'] = data['datetime'].dt.hour
data['mes'] = data['datetime'].dt.month
data.drop(columns=['fechahora', 'datetime'], inplace=True)

# %%
data.head()
# Out:
#    diasemana  temp  op_nubes  temp_rocio  irrad  precip_agua  hum_rel   rand  \
# 0          0  12.6      20.5         6.8    0.0         18.4     68.1  93854
# 1          0  11.8      21.6         7.5    0.0         18.4     74.8   4852
# 2          0  11.0      25.1         7.7    0.0         18.2     80.3   5365
# 3          0  10.5      58.0         7.6    0.0         17.9     82.5   4867
# 4          0  10.4      53.8         7.7    0.0         18.9     83.4   4131
#
#    presion  dir_viento  vel_viento  vel_viento_2  consumo  hora  mes
# 0    979.3         121         1.4          5.04    4.269     0    3
# 1    979.1         121         2.1          7.56    4.246     1    3
# 2    978.5         125         2.1          7.56    4.261     2    3
# 3    978.3         130         1.7          6.12    4.232     3    3
# 4    978.5         144         1.8          6.48    4.237     4    3

# %% [markdown]
# **2. Resumen estadístico del conjunto de datos de entrada:** La estadística descriptiva recolecta y analiza el conjunto de datos de entrada con el objetivo de describir las características y comportamientos de este conjunto mediante las siguientes medidas resumen: número total de observaciones (count), media (mean), desviación estándar (std), valor mínimo (min), valor máximo (max) y los valores de los diferentes cuartiles (25%, 50%, 75%).

# %%
# Datos estadísticos de cada uno de los atributos

data.describe()
# Out:
#          diasemana         temp     op_nubes   temp_rocio        irrad  \
# count  9405.000000  9398.000000  9405.000000  9405.000000  9400.000000
# mean      0.714514    15.953011    30.559755     8.964774   176.360957
# std       0.451670     6.351362    28.614943     5.774114   254.941743
# min       0.000000     1.500000     0.000000   -12.800000     0.000000
# 25%       0.000000    11.100000     4.300000     5.300000     0.000000
# 50%       1.000000    15.100000    22.300000     9.000000     7.000000
# 75%       1.000000    21.175000    52.000000    13.700000   311.000000
# max       1.000000    32.600000    97.000000    21.500000   962.000000
#
#        precip_agua      hum_rel          rand      presion   dir_viento  \
# count  9405.000000  9405.000000   9405.000000  9405.000000  9405.000000
# mean     19.570207    64.765263   6533.634131   985.742616   187.965338
# std       7.721393    13.370106   2215.011120     6.694269    96.882310
# min       2.200000    21.700000   3000.000000   958.400000     0.000000
# 25%      13.500000    55.100000   4760.000000   982.500000   108.000000
# 50%      18.700000    65.700000   6552.000000   986.200000   192.000000
# 75%      25.700000    75.000000   8263.000000   990.100000   269.000000
# max      46.400000    96.000000  93854.000000  1004.800000   360.000000
#
#         vel_viento  vel_viento_2      consumo         hora          mes
# count  9405.000000   9405.000000  9405.000000  9405.000000  9405.000000
# mean      2.449059      8.816612    17.511131    11.498671     6.284211
# std       1.601361      5.764898    12.133444     6.921103     3.444975
# min       0.000000      0.000000     0.000000     0.000000     1.000000
# 25%       1.300000      4.680000     7.810000     6.000000     3.000000
# 50%       2.100000      7.560000    14.363000    11.000000     6.000000
# 75%       3.200000     11.520000    23.574000    17.000000     9.000000
# max      11.700000     42.120000    77.258000    23.000000    12.000000

# %% [markdown]
# **3. ¿Falta algún dato? Comprobar si hay algun missing data (Nan, null...)**

# %%
# Comprobar si falta algún dato y en qué atributo

data.isna().sum()
# Out:
# diasemana       0
# temp            7
# op_nubes        0
# temp_rocio      0
# irrad           5
# precip_agua     0
# hum_rel         0
# rand            0
# presion         0
# dir_viento      0
# vel_viento      0
# vel_viento_2    0
# consumo         0
# hora            0
# mes             0
# dtype: int64

# %% [markdown]
# Si faltan datos, completa las casillas vacias con el valor medido anterior del atributo: utiliza *X["Columna"].fillna(method='XXXX', inplace=True)*

# %%
# Si falta algún dato, imputar valores 

data.fillna(method='ffill', inplace=True)

# %%
# Compruebo que efectivamente no hay Nan
data.isna().sum()
# Out:
# diasemana       0
# temp            0
# op_nubes        0
# temp_rocio      0
# irrad           0
# precip_agua     0
# hum_rel         0
# rand            0
# presion         0
# dir_viento      0
# vel_viento      0
# vel_viento_2    0
# consumo         0
# hora            0
# mes             0
# dtype: int64

# %% [markdown]
# ## **3. Visualizar los datos**
#
# Una manera visual de entender los datos de entrada es mendiante la visualización de las siguientes gráficas.
# 1. Histograma.
# 2. Curva de densidad.
# 3. Boxplots.
# 4. Matriz de correlación.

# %% [markdown]
# **1. Histograma**
#
# Respresentación gráfica de cada uno de los atributos en forma de barras, donde la superficie de la barra es proporcional a la frecuencia de los valores representados.

# %%
histograma = data.hist(xlabelsize=10, ylabelsize=10, bins=100, figsize=(10, 10))

# %% [markdown]
# **2. Gráfico de densidades**
#
# Visualiza la distribución de los datos. Es una variable del histograma, pero elimina el ruido, por lo que son mejores para determinar la forma de distribución de un atributo. Lo spicos del gráfico de densidad ayudan a mostrar dónde los valores se concentran más.

# %%
density = data.plot(kind='kde', x=4, subplots=True, legend=True, layout=(5, 5), figsize=(15, 15), sharex=False,
                        fontsize=8, stacked=True)

# %% [markdown]
# **3. Boxplots**
#
# El boxplot (diagrama de caja) nos permite identificar los valores atípicos y comparar distribuciones. Además, se conoce como se distribuyen el 50% de los valores (dentro de la caja).

# %%
atributos_boxplot = data.plot(kind='box', subplots=True, layout=(4, 4), figsize=(11, 11), sharex=False,
                                 sharey=False, fontsize=10)

# %% [markdown]
# **4. Matriz de correlación**
#
# * ¿Qué característica(s) **no** tiene(n) ninguna correlación con la variable target?

# %%
# Otra librería de visualización de datos
import seaborn as sns

# Cálculo de coeficientes de correlación
corr = data.corr(method='pearson') 

# Quitar valores repetidos
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True
  
f, ax = plt.subplots(figsize=(16, 14))
#Generar Heat Map,
sns.heatmap(corr, annot=True, fmt=".2f" , mask=mask,)
    # xticks
plt.xticks(range(len(corr.columns)), corr.columns);
    # yticks
plt.yticks(range(len(corr.columns)), corr.columns)
    # plot
plt.show()
# Out:
# <ipython-input-17-6b3143d390ae>:8: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   mask = np.zeros_like(corr, dtype=np.bool)

# %% [markdown]
# ## *4. Preparar los datos*
#
#
# 1. LabelEncoding (si existen datos categóricos).
# 2. Feature engineering (proceso iterativo).
# 3. Transformación (escalado): una vez estés divididos los datos de train y test.

# %% [markdown]
# Primero, divido los datos en *atributos*: **X** (features) y *etiquetas*: **y** (target)

# %%
# Atributos X (features); etiquetas y (target)

X = data.drop(['consumo'], axis=1) 
y = data['consumo']

# %% [markdown]
# **2. Feature engineering**
#
# Observando la matriz de correlación, **eliminar los atributos/características que no tengan ninguna correlación con la variable target (y)**.

# %%
# Elimino el atributo que tiene correlación cerca de 0 con el resto de características.

X.drop(['rand', 'vel_viento_2', 'presion'], axis=1, inplace=True)

# %% [markdown]
# ## *5. Dividir los datos*
#
# Dividir los datos en:
# * X_train, y_train
# * X_val, y_val

# %%
from sklearn.model_selection import train_test_split

test_size = 0.2  # porcentaje de los datos de entrada que utilizaré para validar el modelo

# Divido los datos en datos de entreno, validación y prueba
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size,
                                                    shuffle=False)

# %% [markdown]
# **Transformación (escalado).**
#
# * En este ejemplo no se escalan los datos, pero se podría hacer descomentando el código de abajo y cambiando X_train, X_test e X_val por X_train_scaled, X_test_scaled, X_val_scaled.
#
# * **Si lo estimais oportuno**, escalar los datos utilizando un método de escalado **(StandardScaler()/MinMaxScaler())**
#
# <img src="https://raw.githubusercontent.com/sbarja/curso-intro-machine-learning-2023/main/figuras/scaling.png" alt="Drawing" style="width: 50px;"/>

# %%
# Escalado de datos (si procede)

#from sklearn.preprocessing import MinMaxScaler, StandardScaler

#scaler =  StandardScaler()
#X_train_scaled = scaler.fit_transform(X_train)
#X_train_scaled

#X_test_scaled = scaler.fit_transform(X_test)
#X_test_scaled

# %%
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=test_size,
                shuffle=False)

# %% [markdown]
# ## *6. Construcción y evaluación de modelos*

# %% [markdown]
# * Selecciona **RMSE** como métrica de evaluación.
# * Evalúa los algoritmos de regresión utilizados en la sesión 5 que estimes oportunos. Puedes buscar más en la librería scikitlearn.

# %%
from sklearn.linear_model import LinearRegression
from sklearn import svm
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor


num_folds = 5
error_metrics = {'neg_root_mean_squared_error'} 
models = {('LR', LinearRegression()),
           ('DTR', DecisionTreeRegressor()), ('RFR', RandomForestRegressor())}


results = [] # guarda los resultados de las métricas de evaluación
names = []  # Nombre de cada algoritmo
msg = []  # imprime el resumen del método de cross-validation


from sklearn.model_selection import KFold, cross_val_score, GridSearchCV

ite = 0

# Entreno con validación cruzada
for scoring in error_metrics:

    print('Métrica de evaluación: ', scoring)
    for name, model in models:
        print('Modelo ', name)
        cross_validation = KFold(n_splits=num_folds, shuffle=False)
        cv_results = cross_val_score(model, X_train, y_train, cv=cross_validation, scoring=scoring)
        results.append(cv_results)
        if ite == 0:
          names.append(name)
        resume = (name, cv_results.mean(), cv_results.std())
        msg.append(resume)
    print(msg)

    # Comparar resultados entre algoritmos
    fig = plt.figure()
    fig.suptitle('Comparación de algoritmos con métrica de evaluación: %s' %scoring)
    ax = fig.add_subplot(111)
    ax.set_xlabel('Modelos candidatos')
    ax.set_ylabel('%s' %scoring)
    plt.boxplot(results)

    ax.set_xticklabels(names)
    plt.show()

    results = []

    ite += 1
# Out:
# Métrica de evaluación:  neg_root_mean_squared_error
# Modelo  RFR
# Modelo  DTR
# Modelo  LR
# [('RFR', -7.54923863234078, 3.120353152686845), ('DTR', -8.193277049461976, 2.8221809562227285), ('LR', -11.475091067650268, 2.8847813894902674)]

# %% [markdown]
# * **¿Cuál obtiene mejores resultados?**
# * **¿Qué RMSE promedio obtiene?**

# %% [markdown]
# ## *7. Ajustar hiperparámetros*
#
# Pasos para realizar el hiperajuste de los parámetros:
#
# * Métrica para optimizar: **RMSE**
# * Definir los rangos de los parámetros de búsqueda que estimes oportunos: *params*

# %%
# Ajustar los hiperparámetros del algoritmo que os ha dado mejores resultados en el training
from sklearn.model_selection import TimeSeriesSplit, cross_val_score, GridSearchCV, KFold


#RandomForestClassifier
modelo = RandomForestRegressor()
params = {
     'n_estimators': [500, 1000], #default=100
     'min_samples_split': [2,5], #default=2
     'max_features': ['auto']  #default='auto'
 }
scoring='neg_root_mean_squared_error'
cross_validation = KFold(n_splits=5)
my_cv = cross_validation.split(X_val, y_val)
gsearch = GridSearchCV(estimator=modelo, param_grid=params, scoring=scoring, cv=my_cv)
gsearch.fit(X_val, y_val)

print("Mejor resultado: %f utilizando los siguientes hiperparámetros %s" % (gsearch.best_score_, gsearch.best_params_))
means = gsearch.cv_results_['mean_test_score']
stds = gsearch.cv_results_['std_test_score']
params = gsearch.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
     print("%f (%f) with: %r" % (mean, stdev, param))
# Out:
# Mejor resultado: -9.416185 utilizando los siguientes hiperparámetros {'max_features': 'auto', 'min_samples_split': 5, 'n_estimators': 500}
# -9.470066 (1.791394) with: {'max_features': 'auto', 'min_samples_split': 2, 'n_estimators': 500}
# -9.440157 (1.802333) with: {'max_features': 'auto', 'min_samples_split': 2, 'n_estimators': 1000}
# -9.416185 (1.825366) with: {'max_features': 'auto', 'min_samples_split': 5, 'n_estimators': 500}
# -9.436508 (1.803477) with: {'max_features': 'auto', 'min_samples_split': 5, 'n_estimators': 1000}

# %% [markdown]
# ## *8. Evaluación final del modelo*

# %% [markdown]
# Métricas de evaluación:
#   * RMSE
#
# **Entrena el modelo con los hiperparámetros óptimos encontrados en el apartado anterior y realiza las predicciones.**

# %%
from sklearn.metrics import mean_squared_error
import numpy as np


# Entrena al modelo seleccionado con los hiperparámetros seleccionados y realiza las predicciones

modelo_final = RandomForestRegressor(max_features='auto', min_samples_split=2,  n_estimators=1000)
modelo_final.fit(X_train,y_train)  # Se entrena al modelo RF
y_predict = modelo_final.predict(X_test)  # Se calculan las predicciones


mse = mean_squared_error(y_test, y_predict)
rmse = np.sqrt(mse)
print("RMSE:", rmse)


y_predict
# Out:
# RMSE: 11.668691451675365
# array([32.291945, 32.063558, 32.118764, ...,  4.227772,  5.775328,
#         5.57516 ])

# %%
import matplotlib.pyplot as plt
import seaborn as sns


plt.figure(figsize=(25, 10))
sns.lineplot(range(len(y_test)), y_test, label="Real")
sns.lineplot(range(len(y_predict)), y_predict, label="Estimado")
plt.title("Consumo real vs estimado")
plt.xlabel("Tiempo (horas)")
plt.ylabel("Etiqueta (Consumo edificio kWh)")
plt.legend(loc="upper left")
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Los resultados no son muy precisos... volvemos al paso número 2 (feature selection) y creamos nuevas variables de entrada
#
#
# <img src="https://raw.githubusercontent.com/sbarja/curso-intro-machine-learning-2023/main/figuras/creacion-modeloML.png" alt="Drawing" style="width: 50px;"/>

# %%
# Creamos variables pasadas "lag variables" del target.

data['consumo_24h'] = data['consumo'].shift(24) # Crea una lag variable de 24 horas (1 día)
data['consumo_48h'] = data['consumo'].shift(48) # Crea una lag variable de 48 horas (2 días)
data['consumo_168h'] = data['consumo'].shift(168) # Crea una lag variable de 168 horas (1 semana)

# %% [markdown]
# Ahora tenemos 3 features más (consumo_24h, consumo_48h, consumo_168h)

# %%
data
# Out:
#       diasemana  temp  op_nubes  temp_rocio  irrad  precip_agua  hum_rel  \
# 0             0  12.6      20.5         6.8    0.0         18.4     68.1
# 1             0  11.8      21.6         7.5    0.0         18.4     74.8
# 2             0  11.0      25.1         7.7    0.0         18.2     80.3
# 3             0  10.5      58.0         7.6    0.0         17.9     82.5
# 4             0  10.4      53.8         7.7    0.0         18.9     83.4
# ...         ...   ...       ...         ...    ...          ...      ...
# 9400          0  12.6      51.4         7.8   39.0         15.2     72.4
# 9401          0  11.7      93.4         7.7    0.0         14.7     76.6
# 9402          0  11.1      95.7         7.5    0.0         14.1     78.9
# 9403          0  10.6      94.9         7.3    0.0         13.7     80.0
# 9404          0  10.4      92.1         7.3    0.0         13.4     80.9
#
#        rand  presion  dir_viento  vel_viento  vel_viento_2  consumo  hora  \
# 0     93854    979.3         121         1.4          5.04    4.269     0
# 1      4852    979.1         121         2.1          7.56    4.246     1
# 2      5365    978.5         125         2.1          7.56    4.261     2
# 3      4867    978.3         130         1.7          6.12    4.232     3
# 4      4131    978.5         144         1.8          6.48    4.237     4
# ...     ...      ...         ...         ...           ...      ...   ...
# 9400   5076    996.4         176         2.1          7.56    8.175    17
# 9401   6478    996.7         188         1.7          6.12    7.812    18
# 9402   9067    997.1         204         1.3          4.68    7.863    19
# 9403   8624    997.4         211         1.2          4.32   10.384    20
# 9404   8771    997.6         220         1.1          3.96    8.904    21
#
#       mes  consumo_24h  consumo_48h  consumo_168h
# 0       3          NaN          NaN           NaN
# 1       3          NaN          NaN           NaN
# 2       3          NaN          NaN           NaN
# 3       3          NaN          NaN           NaN
# 4       3          NaN          NaN           NaN
# ...   ...          ...          ...           ...
# 9400    3       32.481       33.710         8.179
# 9401    3       31.315       31.647         8.080
# 9402    3       27.026       29.220         9.885
# 9403    3       21.372       21.675        14.405
# 9404    3       16.696       19.055        15.318
#
# [9405 rows x 18 columns]

# %%
data.isna().sum()
# Out:
# diasemana         0
# temp              0
# op_nubes          0
# temp_rocio        0
# irrad             0
# precip_agua       0
# hum_rel           0
# rand              0
# presion           0
# dir_viento        0
# vel_viento        0
# vel_viento_2      0
# consumo           0
# hora              0
# mes               0
# consumo_24h      24
# consumo_48h      48
# consumo_168h    168
# dtype: int64

# %% [markdown]
# Eliminamos los nan, originados por la creacion de las variables lag.

# %%
data = data.dropna()   # elimina todas las filas que contenga algún Nan

# %%
data.isna().sum()
# Out:
# diasemana       0
# temp            0
# op_nubes        0
# temp_rocio      0
# irrad           0
# precip_agua     0
# hum_rel         0
# rand            0
# presion         0
# dir_viento      0
# vel_viento      0
# vel_viento_2    0
# consumo         0
# hora            0
# mes             0
# consumo_24h     0
# consumo_48h     0
# consumo_168h    0
# dtype: int64

# %% [markdown]
# ### Comprobamos si las nuevas features añadidas tienen correlación con la etiqueta (consumo)

# %%
# Otra librería de visualización de datos
import seaborn as sns

# Cálculo de coeficientes de correlación
corr = data.corr(method='pearson') 

# Quitar valores repetidos
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True
  
f, ax = plt.subplots(figsize=(16, 14))
#Generar Heat Map,
sns.heatmap(corr, annot=True, fmt=".2f" , mask=mask,)
    # xticks
plt.xticks(range(len(corr.columns)), corr.columns);
    # yticks
plt.yticks(range(len(corr.columns)), corr.columns)
    # plot
plt.show()
# Out:
# <ipython-input-32-6b3143d390ae>:8: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   mask = np.zeros_like(corr, dtype=np.bool)

# %% [markdown]
# ### 5. Divido los datos

# %%
# Atributos X (features); etiquetas y (target)

X = data.drop(['consumo'], axis=1) 
y = data['consumo']

# %%
from sklearn.model_selection import train_test_split

test_size = 0.2  # porcentaje de los datos de entrada que utilizaré para validar el modelo

# Divido los datos en datos de entreno, validación y prueba
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size,
                                                    shuffle=False)


X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=test_size,
                shuffle=False)

# %% [markdown]
# ### 6. Construcción y evaluación de modelos

# %%
from sklearn.linear_model import LinearRegression
from sklearn import svm
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor


num_folds = 5
error_metrics = {'neg_root_mean_squared_error'} 
models = {('LR', LinearRegression()),
           ('DTR', DecisionTreeRegressor()), ('RFR', RandomForestRegressor())}


results = [] # guarda los resultados de las métricas de evaluación
names = []  # Nombre de cada algoritmo
msg = []  # imprime el resumen del método de cross-validation


from sklearn.model_selection import KFold, cross_val_score, GridSearchCV

ite = 0

# Entreno con validación cruzada
for scoring in error_metrics:

    print('Métrica de evaluación: ', scoring)
    for name, model in models:
        print('Modelo ', name)
        cross_validation = KFold(n_splits=num_folds, shuffle=False)
        cv_results = cross_val_score(model, X_train, y_train, cv=cross_validation, scoring=scoring)
        results.append(cv_results)
        if ite == 0:
          names.append(name)
        resume = (name, cv_results.mean(), cv_results.std())
        msg.append(resume)
    print(msg)

    # Comparar resultados entre algoritmos
    fig = plt.figure()
    fig.suptitle('Comparación de algoritmos con métrica de evaluación: %s' %scoring)
    ax = fig.add_subplot(111)
    ax.set_xlabel('Modelos candidatos')
    ax.set_ylabel('%s' %scoring)
    plt.boxplot(results)

    ax.set_xticklabels(names)
    plt.show()

    results = []

    ite += 1
# Out:
# Métrica de evaluación:  neg_root_mean_squared_error
# Modelo  RFR
# Modelo  DTR
# Modelo  LR
# [('RFR', -4.977440029958961, 1.3717728037675183), ('DTR', -6.748603198919116, 1.5191360401144096), ('LR', -5.416160688710127, 1.3848882714392545)]

# %% [markdown]
# ### 7. Ajustar hiperparámetros

# %%
# Ajustar los hiperparámetros del algoritmo que os ha dado mejores resultados en el training
from sklearn.model_selection import TimeSeriesSplit, cross_val_score, GridSearchCV, KFold


#RandomForestClassifier
modelo = RandomForestRegressor()
params = {
     'n_estimators': [500, 1000], #default=100
     'min_samples_split': [2,5], #default=2
     'max_features': ['auto']  #default='auto'
 }
scoring='neg_root_mean_squared_error'
cross_validation = KFold(n_splits=5)
my_cv = cross_validation.split(X_val, y_val)
gsearch = GridSearchCV(estimator=modelo, param_grid=params, scoring=scoring, cv=my_cv)
gsearch.fit(X_val, y_val)

print("Mejor resultado: %f utilizando los siguientes hiperparámetros %s" % (gsearch.best_score_, gsearch.best_params_))
means = gsearch.cv_results_['mean_test_score']
stds = gsearch.cv_results_['std_test_score']
params = gsearch.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
     print("%f (%f) with: %r" % (mean, stdev, param))
# Out:
# Mejor resultado: -10.050279 utilizando los siguientes hiperparámetros {'max_features': 'auto', 'min_samples_split': 2, 'n_estimators': 1000}
# -10.082467 (3.684496) with: {'max_features': 'auto', 'min_samples_split': 2, 'n_estimators': 500}
# -10.050279 (3.555730) with: {'max_features': 'auto', 'min_samples_split': 2, 'n_estimators': 1000}
# -10.084727 (3.628748) with: {'max_features': 'auto', 'min_samples_split': 5, 'n_estimators': 500}
# -10.095611 (3.574192) with: {'max_features': 'auto', 'min_samples_split': 5, 'n_estimators': 1000}

# %% [markdown]
# ### 8. Evaluación final del modelo

# %%
# Entrena al modelo seleccionado con los hiperparámetros seleccionados y realiza las predicciones

modelo_final = RandomForestRegressor(max_features='auto', min_samples_split=2,  n_estimators=500)
modelo_final.fit(X_train,y_train)  # Se entrena al modelo RF
y_predict = modelo_final.predict(X_test)  # Se calculan las predicciones


mse = mean_squared_error(y_test, y_predict)
rmse = np.sqrt(mse)
print("RMSE:", rmse)

y_predict
# Out:
# RMSE: 7.689361430162389
# array([13.301912, 16.293126, 14.13827 , ..., 11.98857 , 11.479948,
#        12.354766])

# %%
import matplotlib.pyplot as plt
import seaborn as sns


plt.figure(figsize=(25, 10))
sns.lineplot(range(len(y_test)), y_test, label="Real")
sns.lineplot(range(len(y_predict)), y_predict, label="Estimado")
plt.title("Consumo real vs estimado")
plt.xlabel("Tiempo (horas)")
plt.ylabel("Etiqueta (Consumo edificio kWh)")
plt.legend(loc="upper left")
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ## Las predicciones han mejorado con respecto a la primera iteración!!
